# %%
from sklearn.datasets import load_digits
digits = load_digits()
# Affichage des 10 premières images
import matplotlib.pyplot as plt
fig = plt.figure()
for i, digit in enumerate(digits.images[:10]):
    fig.add_subplot(1,10,i+1)
    plt.imshow(digit)
plt.show()

# %%
digits =load_digits()
X, y = digits.data, digits.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.90)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
clf = BaggingClassifier(tree.DecisionTreeClassifier(),
max_samples=0.5, max_features=0.5, n_estimators=200)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = clf.score(X_test,y_test)
print(accuracy)
# Out:
# 0.8992583436341162

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=200)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = clf.score(X_test,y_test)
print(accuracy)
# Out:
# 0.9202719406674907

# %%
#calcul de la valeur de accuracy sur 100 tirages
valeur=100
accuracies=[]
for i in range (valeur):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.90)
    clf = RandomForestClassifier(n_estimators=200)
    clf.fit(X_train, y_train)
    Z = clf.predict(X_test)
    accuracy = clf.score(X_test,y_test)
    accuracies.append(accuracy)
#print(accuracies)

# %%
plt.plot(accuracies)

# %%
import numpy as np
moyenne=np.mean(accuracies)
moyenne
# Out:
# 0.9102781211372064

# %%
ecart_type=np.std(accuracies)
ecart_type
# Out:
# 0.013033042707135692

# %%
#Construire le graphique accuracy VS n_estimators
list_random_forest=list()
for i in range (1,200,10):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.90)
        clf = RandomForestClassifier(n_estimators=i)
        clf.fit(X_train, y_train)
        Z = clf.predict(X_test)
        accuracy = clf.score(X_test,y_test)
        list_random_forest.append(accuracy)
print( list_random_forest)
# Out:
# [0.5006180469715699, 0.8355995055624228, 0.8788627935723115, 0.88442521631644, 0.8733003708281829, 0.8665018541409147, 0.8646477132262052, 0.9184177997527813, 0.9165636588380717, 0.9110012360939431, 0.9085290482076638, 0.9122373300370828, 0.9283065512978986, 0.899876390605686, 0.9239802224969098, 0.896168108776267, 0.904202719406675, 0.9221260815822002, 0.9035846724351051, 0.9140914709517923]

# %%
plt.plot(list_random_forest)

# %%
#utilisation du classifieur ExtraTreesClassifier
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators=200)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = clf.score(X_test,y_test)
print(accuracy)
# Out:
# 0.9406674907292955
